# %%
import numpy as np

# Create a NumPy array
numpy_array = np.array([1, 2, 3, 4, 5])
print("NumPy Array:", numpy_array)

# Perform a basic operation (add 10 to each element)
numpy_array_plus_10 = numpy_array + 10
print("NumPy Array + 10:", numpy_array_plus_10)
# Out:
# NumPy Array: [1 2 3 4 5]
# NumPy Array + 10: [11 12 13 14 15]

# %%
import pandas as pd

# Create a Pandas Series
pandas_series = pd.Series([10, 20, 30, 40, 50])
print("Pandas Series:\n", pandas_series)

# Create a Pandas DataFrame
data = {'Column A': [1, 2, 3], 'Column B': [4, 5, 6]}
pandas_df = pd.DataFrame(data)
print("\nPandas DataFrame:\n", pandas_df)

# Select a column
print("\nSelect 'Column A':\n", pandas_df['Column A'])
# Out:
# Pandas Series:
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# Pandas DataFrame:
#     Column A  Column B
# 0         1         4
# 1         2         5
# 2         3         6
#
# Select 'Column A':
#  0    1
# 1    2
# 2    3
# Name: Column A, dtype: int64

# %% [markdown]
# Here are some examples for data visualization with Matplotlib and Seaborn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Generate some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a simple plot using Matplotlib
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title("Sine Wave using Matplotlib")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# Create a simple scatter plot using Seaborn
data = {'col1': np.random.rand(50), 'col2': np.random.rand(50)}
seaborn_df = pd.DataFrame(data)

plt.figure(figsize=(8, 4))
sns.scatterplot(x='col1', y='col2', data=seaborn_df)
plt.title("Scatter Plot using Seaborn")
plt.xlabel("Column 1")
plt.ylabel("Column 2")
plt.grid(True)
plt.show()

# %% [markdown]
# Finally, let's look at a basic example using Scikit-learn for a simple linear regression.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1) # Reshape for scikit-learn
y = np.array([2, 4, 5, 4, 5])

# Create a Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction
prediction = model.predict([[6]])
print("Prediction for X=6:", prediction[0])

# Get the coefficients
print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Prediction for X=6: 5.8
# Coefficient: 0.6
# Intercept: 2.2
